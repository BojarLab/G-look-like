# %%
import sys
import io
import matplotlib.pyplot as plt
from functions import plot_Binding_vs_Flexibility_and_SASA_with_stats
from analyses import metric_df_, properties

stdout_backup = sys.stdout  # Backup original stdout
sys.stdout = io.StringIO()  # Redirect stdout to a buffer

lectin= "AAL"

plot_Binding_vs_Flexibility_and_SASA_with_stats(metric_df_[lectin], lectin, properties["motif"])

plt.show()

# %%
lectin= "CMA"
plot_Binding_vs_Flexibility_and_SASA_with_stats(metric_df_[lectin], lectin, properties["motif"])

plt.show()

# %%
lectin= "SNA"
plot_Binding_vs_Flexibility_and_SASA_with_stats(metric_df_[lectin], lectin, properties["motif"])

plt.show()
